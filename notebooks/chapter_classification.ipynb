# %% [markdown]
# ## Imports

# %%
# Sklearn module
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas as pd, xgboost, numpy, textblob, string

# Keras stuff -- Commented out as not used yet
# from keras.preprocessing import text, sequence
# from keras import layers, models, optimizers

# Regex
import re

# Stopwords
import nltk
nltk.download('stopwords')
stop = nltk.corpus.stopwords.words('english')
import json

print(stop)
from pylatexenc.latex2text import LatexNodes2Text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pritamsukumar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# ## Data Preparation

# %%
subject_to_check = 'MTH'
# Load the dataset
labels, texts = [], []
with open('../data/qs_topicwise.json') as json_data:
    all_questions = json.load(json_data)

words_to_remove = ["rightarrow", "hence", "frac", "text", "sqrt", "times", "value", "amp", "statement", "will", "equal", "number", "tan", "now", "can", "two", "get", "true", "lambda"]
# words_to_remove += stop

data_df = pd.DataFrame(columns=['curriculum', 'subject', 'question_text', 'chapter'])
questions = []
i = 0

# Regex pattern for keeping only alphabets and numbers
pattern = re.compile('[\W_]+')
nonutf8pattern = re.compile('[\u0080-\uffff]')

for question in all_questions:
    try: # So that python doesn't crash on individual question exceptions
        question_text = question['question_text'].lower()
        
        question_text = pattern.sub(" ", question_text)
        question_text = nonutf8pattern.sub(" ", question_text)


        # Remove extra whitespaces
        question_text = " ".join([word for word in question_text.split() if word not in words_to_remove])
        question_text = " ".join(question_text.split())

        
        # Keep only alphanumeric characters
        subject = question['subject']
        curriculum = question['curriculum']
        grade = question['grade']
        if("JEE" in curriculum and subject in subject_to_check):
            data_df.loc[i] = [curriculum, subject, question_text, question['chapter']]
            i += 1
    except Exception as e:
        print(e)

trainDF = pd.DataFrame(columns=['text', 'label'])

# trainDF.replace(words_to_replace, "")
trainDF['text'] = data_df['question_text']
trainDF['label'] = data_df['chapter']

display(trainDF.head)
# Out:
# <bound method NDFrame.head of                                                    text  \
# 0     among the statements given below which one is ...
# 1                                  sin 1 left 1 2 right
# 2                      the principal domain of cos 𝑥 is
# 3                          the principal domain of 𝑥 is
# 4                                 1 left sin pi 2 right
# 5                         sin 1 left sin 𝑥 right 𝑥 if 𝑥
# 6     revision exercise 5 mins the students should a...
# 7     what domain restrictions be imposed on the fun...
# 8           the principal solutions of sin x frac12 are
# 9                the general solution of sin theta 0 is
# 10                                  if cos x cos y then
# 11           if sin x 1 2 x in left 0 pi 2 right then x
# 12      the of principal solutions of cos x 1 sqrt2 are
# 13    cot 1 cos 1 cos x where alpha is some arbitrar...
# 14      if cos 1 x cos 1 y2 then 4x 2 4xy cos y 2 is to
# 15         the principal of 1 left cot 43 pi 4 right is
# 16    if f left x right 2 1 x sin 1 left 2x 1 x 2 ri...
# 17                         1 3 sin 1 left sqrt3 2 right
# 18                  the of 2 sec 1 2 cot 2 cosec 1 3 is
# 19     if cos 1 x cos 1 y cos 1 z 3 then xy yz zx is to
# 20    let f left 1 1 right b be a function defined b...
# 21                        if sin 1 3x sin 1 4x 2 then x
# 22    the of a for which ax 2 sin 1 x 2 2x 2 cos 1 x...
# 23                          if sin 1 x cos 1 x 1 x then
# 24    the trigonometric equation sin 1 x 2 sin 1 a h...
# 25    for some x 1 1 we have cos 1 x 1 x then the of...
# 26      if cos 1 x cos 1 y2 then 4x 2 4xy cos y 2 is to
# 27                     the of sin 1 frac12 cosec 1 2 is
# 28     solution of the equation 1 x 1 1 x 1 x 1 1 3x is
# 29    the of cos left pi 6 cos 1 left 1 2 right righ...
# ...                                                 ...
# 6949                                 if sin x 4 5 sec x
# 6950  for an angle a which does not exceed 90 circ c...
# 6951  in triangle abc right angled at b if a 3 find ...
# 6952  in delta pqr right angled at q qr 8 cm and the...
# 6953                       sec 68 circ is equivalent to
# 6954  which of the following values are not defined ...
# 6955                            2 tan30 circ 1 230 circ
# 6956         which of the following identities is false
# 6957           tan1 circ tan2 circ tan3 circ tan89 circ
# 6958  if the angle of elevation of a bird sitting on...
# 6959  the angles of elevation from points at distanc...
# 6960  the angle of elevation of the top of a flag po...
# 6961      if b 15 then of 4 sin 2b cos 4b sin 6b equals
# 6962     which out of the following identities is false
# 6963    if x sin 45 circ cos 45 circ sin 30 circ then x
# 6964                   the slope of the line 3x 7 5y is
# 6965  find the angle which the line joining the poin...
# 6966  which of the following lines has a higher abso...
# 6967  is the given equation 2x 3y 6 0 going upwards ...
# 6968                                       d dx cosec x
# 6969                       d dx left 3e x 4 cos x right
# 6970  in the figure identify the sign of the slope o...
# 6971  the displacement of a particle varies with tim...
# 6972  the displacement of a particle varies with tim...
# 6973  the displacement of a particle varies with tim...
# 6974  for which of the following functions the insta...
# 6975  differentiation of sin x x using the product r...
# 6976  differentiation of x ln x using the product ru...
# 6977                               d dx left 3x x right
# 6978                            d dx left 2 x e x right
#
#                            label
# 0          Inverse Trigonometry
# 1          Inverse Trigonometry
# 2          Inverse Trigonometry
# 3          Inverse Trigonometry
# 4          Inverse Trigonometry
# 5          Inverse Trigonometry
# 6          Inverse Trigonometry
# 7          Inverse Trigonometry
# 8          Inverse Trigonometry
# 9          Inverse Trigonometry
# 10         Inverse Trigonometry
# 11         Inverse Trigonometry
# 12         Inverse Trigonometry
# 13         Inverse Trigonometry
# 14         Inverse Trigonometry
# 15         Inverse Trigonometry
# 16         Inverse Trigonometry
# 17         Inverse Trigonometry
# 18         Inverse Trigonometry
# 19         Inverse Trigonometry
# 20         Inverse Trigonometry
# 21         Inverse Trigonometry
# 22         Inverse Trigonometry
# 23         Inverse Trigonometry
# 24         Inverse Trigonometry
# 25         Inverse Trigonometry
# 26         Inverse Trigonometry
# 27         Inverse Trigonometry
# 28         Inverse Trigonometry
# 29         Inverse Trigonometry
# ...                          ...
# 6949   Trigonometry - Foundation
# 6950   Trigonometry - Foundation
# 6951   Trigonometry - Foundation
# 6952   Trigonometry - Foundation
# 6953   Trigonometry - Foundation
# 6954   Trigonometry - Foundation
# 6955   Trigonometry - Foundation
# 6956   Trigonometry - Foundation
# 6957   Trigonometry - Foundation
# 6958   Trigonometry - Foundation
# 6959   Trigonometry - Foundation
# 6960   Trigonometry - Foundation
# 6961   Trigonometry - Foundation
# 6962   Trigonometry - Foundation
# 6963   Trigonometry - Foundation
# 6964  Calculus - Differentiation
# 6965  Calculus - Differentiation
# 6966  Calculus - Differentiation
# 6967  Calculus - Differentiation
# 6968  Calculus - Differentiation
# 6969  Calculus - Differentiation
# 6970  Calculus - Differentiation
# 6971  Calculus - Differentiation
# 6972  Calculus - Differentiation
# 6973  Calculus - Differentiation
# 6974  Calculus - Differentiation
# 6975  Calculus - Differentiation
# 6976  Calculus - Differentiation
# 6977  Calculus - Differentiation
# 6978  Calculus - Differentiation
#
# [6979 rows x 2 columns]>

# %% [markdown]
# ### Split into training and testing folds

# %%
# Split data into training and testing folds

train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'], test_size=0.2)

# Label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)
# Out:
# 5583 1396
# 3989    paragraph for question numbers 15 to 17 x 2 y ...
# 6374    the term independent of 𝑥 in 1 𝑥 𝑚 left 1 1 x ...
# 4064    identify the quadrant and mention the correct ...
# 5524    if z cos left pi k right i sin left pi k right...
# 2094    if in an isosceles triangle with base a vertic...
# 515     the function f left x right left sin2x right 2...
# 5353    let pqrs be a rectangle of size 9 3 if it is f...
# 2856                            z log yx is equivalent to
# 4819    for k gt 0 the quadratic equation 2x 2 6x k 0 ...
# 175     the function f x sin 4x cos 2x is a periodic f...
# 4749    find the product of the roots of the quadratic...
# 6385    the middle term in the expansion of x frac1x 1...
# 3009    how many of the following functions have a max...
# 330     geometrically the derivative at any point is t...
# 930     if 𝐼 𝑎 𝑏𝑓 𝑥 𝑑𝑥 and we substitute 𝑥 2𝑡 which of...
# 5180    the coordinate axes is transformed in differen...
# 4115    if the arcs of the same lengths in circles sub...
# 1318    if vec a vec b and vec c are unit vectors sati...
# 3201    let r be the relation such that r x x 2 x is a...
# 3629    tangents pa and pb are drawn from the point p ...
# 1715    one of the roots of the given equation left be...
# 4571    if x 4 x 5 x 2 2 x 3 gt 0 then a possible for ...
# 6200    if the sum of the coefficients in the expansio...
# 4133    if cot x 5 12 then x lies in second quadrant t...
# 5187    if for intersecting lines a 1a 2 b 1b 2 gt 0 t...
# 4937    let k in r and the equation left k 2 right lef...
# 6711    with the use of quantifiers convert the follow...
# 1811    let f left n right left begin matrix n n 1 n 2...
# 5765      if np r 2520 and nc r 21 then n is divisible by
# 3213    if f left x right x 1 x 1 then f left 1 x righ...
#                               ...
# 1650    one hundred identical coins each with probabil...
# 2260    the of sum limits 13 k 1 1 sin left pi 4 left ...
# 5670    find all complex numbers of the form z a ib wh...
# 5211    find the equation of a line that has y interce...
# 3776                  for x 2 4 y 2 1 the foci are at and
# 4112    how many solutions in 0 2 pi are possible for ...
# 4307    the equation p sin x q cos x r has a solution ...
# 6726    the parallelogram is a rhombus if all its side...
# 5346    f 1 and f 2 are feet of perpendiculars from p ...
# 1008    i int limits pi 2 0 sin 10 x cos 10 xdx int li...
# 4298          the minimum of f x sin 4 x cos 4 x 0 x 2 is
# 1555                of outcomes in a bernoulli s trial is
# 2799                                          16 frac23 x
# 3294     find the range of f left x right x 2 x 1 x 2 x 1
# 5075    the following equation gives the angle 𝛼 betwe...
# 3487    finite sets have m and n elements respectively...
# 1643    in a game a coin is tossed 2n m and a player w...
# 2924                           find dy dx for y 3 sin x x
# 2338    consecutive n th and n 1 th terms of an a p is...
# 368     which of the following is about the continuity...
# 6831    in a set of 20 observations each of the observ...
# 2561    what is the locus of the point of intersection...
# 6516                     the of lim limits y to2 5 2 y is
# 3796    find the equation of diameter of the hyperbola...
# 3106         if x log 10 1 2 x x log 10 5 log 10 6 then x
# 2742    let l 1 be a straight line passing through the...
# 5703    if 𝑧 is a complex such that 𝑧 2 then the minim...
# 3372    the set of all x for which f left x right log ...
# 5137    find the equation of the third side of an isos...
# 3647    if the axis of the parabola y 2 4ax its direct...
# Name: text, Length: 5583, dtype: object

# %% [markdown]
# # Feature creation

# %%
# ----- FEATURE ENGINEERING -----
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', binary=True, max_features=3513)
X = count_vect.fit_transform(trainDF['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)

xvalid_count =  count_vect.transform(valid_x)

# %%
x = count_vect.vocabulary_
y = list(x.keys() )
print(sorted(y))
# Out:
# ['00', '000', '000001', '0001', '0002', '002', '01', '02', '025', '04x', '07', '0a', '0c', '0e', '0f', '0x', '0xe', '0z', '10', '100', '1000', '10000', '100000', '1000c', '1001', '100d', '100x', '101', '1011', '1011121314frequency', '1012', '102', '1024', '103', '104', '105', '106', '107', '108', '1080', '109', '10ax', '10b', '10cx', '10i', '10th', '10x', '10y', '11', '110', '11040', '111', '112', '115', '117', '119', '11b', '11d', '11i', '11if', '11t', '11x', '11y', '12', '120', '120g', '121', '1234', '125', '126', '127', '128', '12a', '12i', '12m', '12t', '12x', '12y', '12z', '13', '130', '130p', '135', '136', '1361', '137', '139', '13x', '14', '140', '1400', '1410', '1413', '144', '145', '1450', '1457', '149', '14a', '14x', '14y', '15', '150', '150x', '15101051', '152', '153', '1530', '155', '156', '157', '15b', '15i', '15th', '15x', '16', '160', '162', '164', '169', '16ax', '16q', '16x', '16y', '16z', '17', '1720', '175', '178', '17f', '17th', '17x', '18', '180', '1800', '183', '185', '18e', '18i', '18x', '18xy', '18y', '18z', '18𝑦', '19', '192', '19202122', '192x', '1958', '196', '1986', '1992', '19let', '19x', '1a', '1b', '1c', '1column', '1e', '1f', '1figure', '1g', '1h', '1k', '1m', '1mn', '1n', '1nf', '1q', '1s', '1st', '1t', '1the', '1x', '1y', '1z', '1𝑥', '1𝑦', '20', '200', '2000', '20000', '2002b', '2003', '2008', '2009', '201', '2010', '2011b', '2012', '2012b', '2013', '2013f', '2014', '2015', '2016', '2017', '2020', '2023', '207', '20c', '20i', '20let', '20th', '20x', '20y', '21', '210', '2100', '212', '2128', '215', '216', '2187', '21x', '21y', '22', '220', '2228', '225', '22j', '22t', '22x', '22xdx', '23', '230', '232', '23the', '24', '240', '240g', '243', '243x', '2475', '24i', '24x', '24xy', '24y', '25', '250', '2500', '252', '2520', '253', '255', '256', '25a', '25px', '25x', '25y', '26', '260', '261', '26i', '26x', '27', '270', '2700', '2717y', '2727', '27i', '27x', '27z', '28', '288', '28x', '29', '29x', '2a', '2ab', '2ac', '2acy', '2ar', '2as', '2at', '2ax', '2ay', '2b', '2bt', '2bx', '2by', '2c', '2column', '2cosx', '2cx', '2cxy', '2d', '2dt', '2dx', '2dy', '2e', '2ex', '2f', '2figure', '2fy', '2g', '2given', '2gx', '2h', '2hxy', '2i', '2i3', '2if', '2iy', '2j', '2k', '2kx', '2let', '2logx', '2logxdx', '2m', '2mx', '2n', '2nd', '2o', '2p', '2px', '2q', '2qy', '2r', '2region', '2s', '2sin', '2sin2x', '2t', '2tf', '2the', '2u', '2w', '2x', '2xi', '2xlogxdx', '2xn', '2xy', '2y', '2yi', '2yz', '2z', '2𝑎', '2𝑏', '2𝑓𝑦', '2𝑔𝑥', '2𝑖', '2𝑛', '2𝑡', '2𝑥', '2𝑥𝑦', '2𝑦', '2𝜃', '2𝜋', '30', '300', '3000', '30000', '301', '3069', '30th', '30x', '30y', '31', '31218123', '315', '3195', '32', '321', '32x', '32y', '32𝑦', '33', '333', '3333', '334', '336', '337', '338', '34', '343', '34x', '35', '351', '35m', '36', '360', '361', '365', '368', '36x', '37', '3789108', '379', '38', '380', '39', '392', '3a', '3ab', '3abc', '3abx', '3ac', '3ax', '3b', '3by', '3c', '3cy', '3d', '3dx', '3e', '3f', '3figure', '3g', '3i', '3j', '3k', '3m', '3mn', '3n', '3p', '3r', '3rd', '3s', '3t', '3u', '3x', '3xy', '3y', '3z', '3𝐷', '3𝑓', '3𝑖', '3𝑚', '3𝑥', '3𝑦', '40', '400', '4000', '40000', '4095', '4096', '41', '41024', '414', '414141', '416', '417', '42', '420', '4200', '43', '432', '438', '44', '45', '450', '4500', '453', '45t', '46', '460', '466', '46x', '47', '475', '48', '482', '49', '49n', '4a', '4ab', '4ac', '4at', '4ax', '4ay', '4b', '4bx', '4c', '4cy', '4d', '4dividing', '4dx', '4e', '4f', '4g', '4h', '4i', '4if', '4k', '4lnx', '4m', '4n', '4other', '4r', '4s', '4t', '4th', '4x', '4xdx', '4xy', '4xyz', '4y', '4z', '4𝑓', '4𝑖', '4𝑥', '4𝑥𝑦', '4𝑦', '50', '500', '5000', '5040', '50a', '50b', '50d', '50x', '51', '510', '512', '513', '513x', '52', '520200', '521', '5253', '53', '5346', '5353', '54', '540', '543', '54x', '55', '5500', '56', '560', '561', '567', '567724', '57', '576', '57x', '58', '585', '586', '59', '594', '5a', '5ax', '5b', '5bx', '5c', '5d', '5e', '5f', '5i', '5k', '5kx', '5m', '5n', '5p', '5q', '5t', '5th', '5x', '5xy', '5y',  ...

# %%
count_vect.stop_words_
# Out:
# {'3i2y',
#  '3ix',
#  '3q',
#  'cota',
#  'cotb',
#  'cotc',
#  'coterminous',
#  'cotrapositive',
#  'count',
#  'counters',
#  'countries',
#  'country',
#  'counts',
#  'covering',
#  'covert',
#  'cpb',
#  'cream',
#  'creams',
#  'crew',
#  'cs',
#  'cu',
#  'cubical',
#  'currency',
#  'cutting',
#  'cv',
#  'dac',
#  'daily',
#  'dairy',
#  'dalmatian',
#  'dance',
#  'dash',
#  'dat',
#  'dataclass',
#  'dataheight',
#  'daughters',
#  'daynumber',
#  'dayoption',
#  'ddot',
#  'deal',
#  'dealt',
#  'debate',
#  'december',
#  'decide',
#  'deck',
#  'decompose',
#  'decrease',
#  'defining',
#  'deleted',
#  'deliveries',
#  'demand',
#  'denomination',
#  'dentoes',
#  'depicts',
#  'deposit',
#  'deposited',
#  'deposits',
#  'depth',
#  'derivation',
#  'derive',
#  'descending',
#  'description',
#  'design',
#  'detector',
#  'dg',
#  'dicitionary',
#  'differences',
#  'differentiablenot',
#  'differentials',
#  'differentiating',
#  'differentiations',
#  'diffrential',
#  'directionwe',
#  'directly',
#  'directories',
#  'discarded',
#  'discovered',
#  'discrete',
#  'disease',
#  'dishonest',
#  'disjointregion',
#  'distibuted',
#  'distributionclasses',
#  'doberman',
#  'doctor',
#  'doesn',
#  'doubles',
#  'dr',
#  'draws',
#  'driving',
#  'dropped',
#  'du',
#  'ducks',
#  'dv',
#  'e16',
#  'ea',
#  'earners',
#  'earth',
#  'eastwards',
#  'eb',
#  'eccentriciyt',
#  'economical',
#  'edge',
#  'edx',
#  'ef',
#  'elected',
#  'election',
#  'elimination',
#  'emanating',
#  'emitted',
#  'employees',
#  'enclose',
#  'encounter',
#  'endanoele',
#  'endeanoel',
#  'endlessly',
#  'engineering',
#  'enlarge',
#  'enough',
#  'entire',
#  'entity',
#  'epsilon',
#  'equaliv',
#  'equallydistribute',
#  'equationi',
#  'equivalently',
#  'erases',
#  'erasing',
#  'escape',
#  'eta',
#  'etc',
#  'evaluating',
#  'evening',
#  'evenstatement',
#  'eventsiii',
#  'eventswhich',
#  'everyone',
#  'exam',
#  'examine',
#  'exams',
#  'exchanged',
#  'excluded',
#  'exercise',
#  'exp',
#  'expanding',
#  'expands',
#  'expanses',
#  'expansions',
#  'expected',
#  'expensive',
#  'experiments',
#  'explain',
#  'expresion',
#  'exradius',
#  'extended',
#  'extends',
#  'exterior',
#  'external',
#  'extrema',
#  'ey',
#  'eyes',
#  'faced',
#  'factional',
#  'factorial',
#  'factoring',
#  'factorisation',
#  'factorized',
#  'fahrenheit',
#  'failed',
#  'fails',
#  'falling',
#  'fan',
#  'farther',
#  'fast',
#  'fat',
#  'fatal',
#  'fc',
#  'feeling',
#  'female',
#  'fencing',
#  'file',
#  'fin',
#  'finger',
#  'fingers',
#  'finitely',
#  'fires',
#  'firm',
#  'firms',
#  'fish',
#  'flag',
#  'flaws',
#  'flow',
#  'flower',
#  'flows',
#  'fnd',
#  'fo',
#  'followed',
#  'followinglist',
#  'forecasts',
#  'formation',
#  'formulated',
#  'forward',
#  'frac12p',
#  'frac15',
#  'frac18',
#  'frac1e',
#  'frac1k',
#  'frac1m',
#  'frac1n',
#  'frac1t',
#  'frac1y',
#  'frac1z',
#  'frac23a',
#  'frac32x',
#  'frac34',
#  'frac35',
#  'frac4',
#  'frac43ps',
#  'frac45',
#  'frac5',
#  'frac72',
#  'freely',
#  'freight',
#  'front',
#  'fuel',
#  'funciotn',
#  'functioniiiiiiv',
#  'functionquadrant',
#  'fund',
#  'gab',
#  'gap',
#  'garden',
#  'gave',
#  'gcd',
#  'gd',
#  'ge26',
#  'ge2y',
#  'ge4x',
#  'ge8',
#  'geese',
#  'geometrically',
#  'geometry',
#  'geq1',
#  'geq2',
#  'geq2x',
#  'geq3',
#  'germany',
#  'ghar',
#  'gifts',
#  'goa',
#  'governed',
#  'graduate',
#  'grand',
#  'graphical',
#  'grass',
#  'gravitational',
#  'gravity',
#  'grows',
#  'guessing',
#  'gx',
#  'hae',
#  'hall',
#  'halt',
#  'halting',
#  'halves',
#  'hands',
#  'happen',
#  'haryana',
#  'hasonly',
#  'hastwo',
#  'heating',
#  'heights',
#  'heightweightmean',
#  'hens',
#  'hh',
#  'hindustan',
#  'hline',
#  'home',
#  'hot',
#  'houses',
#  'however',
#  'human',
#  'hunter',
#  'husband',
#  'husky',
#  'hx',
#  'hydrochloric',
#  'hypotenuse',
#  'h𝑥',
#  'i3',
#  'ibt',
#  'idempotent',
#  'ignoring',
#  'iiabscissa',
#  'iiconsider',
#  'iifor',
#  'iiplane',
#  'iiroots',
#  'iistraight',
#  'illness',
#  'illuminated',
#  'immediately',
#  'implicity',
#  'imposed',
#  'inclination',
#  'include',
#  'incomplete',
#  'increment',
#  'independently',
#  'indianoil',
#  'indians',
#  'indigo',
#  'indirect',
#  'individually',
#  'industry',
#  'inersection',
#  'inex',
#  'infer',
#  'inner',
#  'input',
#  'inscribe',
#  'installment',
#  'instances',
#  'int2sec',
#  'int3',
#  'int4',
#  'int5',
#  'int7e',
#  'integera',
#  'integeriv',
#  'integrate',
#  'intelligent',
#  'interesect',
#  'interesting',
#  'international',
#  'intervention',
#  'intoidentify',
#  'intuition',
#  'inviting',
#  'involving',
#  'ion',
#  'is18the',
#  'is4if',
#  'iscontinuous',
#  'isdifferentiable',
#  'isf',
#  'isneither',
#  'ithe',
#  'iw',
#  'ixx',
#  'j1',
#  'jack',
#  'january',
#  'jaya',
#  'jc',
#  'jee',
#  'jerry',
#  'jill',
#  'job',
#  'joined',
#  'journey',
#  'juice',
#  'july',
#  'junction',
#  'june',
#  'juniors',
#  'k2',
#  'kf',
#  'kg',
#  'kink',
#  'knows',
#  'kohli',
#  'konkan',
#  'kota',
#  'kq',
#  'kr',
#  'ks',
#  'kunal',
#  'kxy',
#  'kz',
#  'k𝑦',
#  'labeled',
#  'labrador',
#  'laid',
#  'lamp',
#  'lamps',
#  'language',
#  'languages',
#  'laps',
#  'latera',
#  'latusrecta',
#  'lawii',
#  'lawiii',
#  'lawiv',
#  'layers',
#  'le11',
#  'le15',
#  'le18',
#  'le36',
#  'le3x',
#  'le4x',
#  'le4y',
#  'le7',
#  'le8x',
#  'leads',
#  'learn',
#  'legal',
#  'lemons',
#  'leq3',
#  'leq4x',
#  'leq8',
#  'lettered',
#  'li9ne',
#  'library',
#  'licence',
#  'licences',
#  'liked',
#  'lineif',
#  'listed',
#  'literal',
#  'liters',
#  'litres',
#  'lives',
#  'll',
#  'ln25',
#  'ln3',
#  'ln3x',
#  'ln5x',
#  'lnx',
#  'loan',
#  'locality',
#  'loci',
#  'log6',
#  'logics',
#  'logx',
#  'log𝑎',
#  'log𝑏',
#  'log𝑐',
#  'lose',
#  'lost',
#  'lowest',
#  'loyal',
#  'm0',
#  'madrid',
#  'magnitudes',
#  'malayalam',
#  'male',
#  'males',
#  'managed',
#  'manchester',
#  'mango',
#  'manned',
#  'manners',
#  'mantissa',
#  'map',
#  'mapping',
#  'marathi',
#  'march',
#  'market',
#  'marksnumber',
#  'mass',
#  'master',
#  'material',
#  'mathematicians',
#  'maximums',
#  'maybe',
#  'mc',
#  'me',
#  'mechanical',
#  'medicine',
#  'mediterranean',
#  'melts',
#  'menu',
#  'met',
#  'metal',
#  'methodheight',
#  'mf',
#  'midterm',
#  'miles',
#  'millioniv',
#  'minimal',
#  'minimizes',
#  'minimums',
#  'ministers',
#  'mins',
#  'mistress',
#  'moderately',
#  'moduleafter',
#  'moivre',
#  'momentarily',
#  'monthiii',
#  'moreover',
#  'motor',
#  'mouse',
#  'mouth',
#  'mq',
#  'mqr',
#  'mrn',
#  'mrs',
#  'mrt',
#  'mt',
#  'mth',
#  'mu3',
#  'multiply',
#  'mystery',
#  'n128',
#  'n2',
#  'n8',
#  'nagpur',
#  'named',
#  'napier',
#  'narrow',
#  'navimumbai',
#  'ne4',
#  'near',
#  'nearby',
#  'nearer',
#  'necklaces',
#  'neglecting',
#  'neighbour',
#  'neighbours',
#  'neq0',
#  'newspapers',
#  'ni',
#  'night',
#  'nilpotent',
#  'ninth',
#  'nj',
#  'nk',
#  'nm',
#  'nn',
#  'northwards',
#  'notebook',
#  'notes',
#  'november',
#  'nq',
#  'numberii',
#  'numberzeroan',
#  'nw',
#  'nxdx',
#  'nz',
#  'oabcd',
#  'oac',
#  'oacb',
#  'obd',
#  'objectsstatement',
#  'observe',
#  'observes',
#  'obtaining',
#  'occupied',
#  'occuring',
#  'octant',
#  'october',
#  'odc',
#  'oe',
#  'offer',
#  'often',
#  'oi',
#  'omitted',
#  'omn',
#  'oncircleif',
#  'onhyperbola',
#  'operating',
#  'opqrs',
#  'oqd',
#  'orange',
#  'orders',
#  'originating',
#  'orthonormal',
#  'oscillation',
#  'ot',
#  'others',
#  'otherwise',
#  'outer',
#  'output',
#  'owned',
#  'owner',
#  'p2',
#  'p3',
#  'pac',
#  'pairwise',
#  'paise',
#  'pap',
#  'papers',
#  'parablas',
#  'parabolaif',
#  'parabolic',
#  'parallelepiped',
#  'parallelogrm',
#  'parbola',
#  'parcel',
#  'parcels',
#  'park',
#  'participant',
#  'participants',
#  'participated',
#  'partly',
#  'partner',
#  'pascal',
#  'passenger',
#  'passengers',
#  'passess',
#  'passport',
#  'paths',
#  'patients',
#  'pattern',
#  'pay',
#  'pays',
#  'pc',
#  '𝜆𝑥',
#  '𝜆𝑦'}

# %%
count_vect
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=3500, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
count_vect.get_params
# Out:
# <bound method BaseEstimator.get_params of CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=3500, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)>

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    
    return metrics.accuracy_score(predictions, valid_y)

# %%
# Naive Bayes on Count Vectors
accuracy = train_model(naive_bayes.GaussianNB(), xtrain_count.todense(), train_y, xvalid_count.todense())
print("NB, Count Vectors: ", accuracy)
# Out:
# NB, Count Vectors:  0.4305157593123209
