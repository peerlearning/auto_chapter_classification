# %% [markdown]
# ## Imports

# %%
# Sklearn module
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas as pd, xgboost, numpy, textblob, string

# Keras stuff -- Commented out as not used yet
# from keras.preprocessing import text, sequence
# from keras import layers, models, optimizers

# Regex
import re

# Stopwords
import nltk
nltk.download('stopwords')
stop = nltk.corpus.stopwords.words('english')
import json

from pylatexenc.latex2text import LatexNodes2Text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pritamsukumar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Data Preparation

# %%
subject_to_check = 'MTH'
# Load the dataset
labels, texts = [], []
with open('data/qs_topicwise.json') as json_data:
    all_questions = json.load(json_data)

words_to_remove = ["rightarrow", "hence", "frac", "text", "sqrt", "times", "value", "amp", "statement", "will", "equal", "number", "tan", "now", "can", "two", "get", "true", "lambda"]
# words_to_remove += stop

data_df = pd.DataFrame(columns=['curriculum', 'subject', 'question_text', 'chapter'])
questions = []
i = 0

# Regex pattern for keeping only alphabets and numbers
pattern = re.compile('[^[:alnum:]]+')
nonutf8pattern = re.compile('[\u0080-\uffff]')
questions = all_questions[1:2]

for question in all_questions:
    try: # So that python doesn't crash on individual question exceptions
        question_text = question['question_text'].lower()
        
        question_text = pattern.sub(" ", question_text)
        question_text = nonutf8pattern.sub(" ", question_text)


        # Remove extra whitespaces
        question_text = " ".join([word for word in question_text.split() if word not in words_to_remove])
        question_text = " ".join(question_text.split())

        
        # Keep only alphanumeric characters
        
        subject = question['subject']
        curriculum = question['curriculum']
        grade = question['grade']
        curr_question = {}
        if("JEE" in curriculum and subject in subject_to_check):
            data_df.loc[i] = [curriculum, subject, question_text, question['chapter']]
            i += 1
    except Exception as e:
        print(e)

trainDF = pd.DataFrame(columns=['text', 'label'])

# trainDF.replace(words_to_replace, "")
trainDF['text'] = data_df['question_text']
trainDF['label'] = data_df['chapter']

# %% [markdown]
# ### Split into training and testing folds

# %%
# Split data into training and testing folds

train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'], test_size=0.2)

print(len(train_x), len(valid_x) )

# Label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)
# Out:
# 5583 1396

# %% [markdown]
# # Feature creation

# %%
# ----- FEATURE ENGINEERING -----
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=3500)
X = count_vect.fit_transform(trainDF['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xtrain_count_binary = xtrain_count
xtrain_count_binary[xtrain_count_binary != 0] = 1

xvalid_count =  count_vect.transform(valid_x)
xvalid_count[xvalid_count != 0] = 1
xvalid_count_dense = xvalid_count.todense().astype('str')

# %%
x = count_vect.vocabulary_
y = list(x.keys() )
print(sorted(y))
# Out:
# ['0', '00', '000', '000001', '0001', '0002', '002', '01', '02', '025', '07', '0f', '1', '10', '100', '1000', '10000', '100000', '1000c_', '1001', '100d', '100x', '101', '1011', '1011121314frequency', '1012', '102', '1024', '103', '104', '105', '106', '107', '10ax', '10cx', '10i', '10x', '10y', '11', '110', '112', '115', '117', '119', '11b', '11d', '11i', '11if', '11t', '11x', '11y', '12', '120', '120g', '121', '1234', '125', '126', '127', '128', '12a', '12i', '12m', '12t', '12x', '12y', '12z', '13', '130', '130p_2', '135', '136', '1361', '137', '139', '13x', '14', '140', '1400', '1410', '1413', '144', '145', '1450', '1457', '149', '14a', '14x', '14y', '15', '150', '15b', '15i', '15th', '15x', '16', '160', '162', '169', '16ax', '16q', '16x', '16y', '16z_2z_3z_4', '17', '1720', '175', '178', '17f', '17th', '17x', '18', '180', '1800', '183', '185', '18e', '18i', '18x', '18xy', '18y', '18z', '18𝑦', '19', '192', '19202122', '192x', '1958', '196', '1986', '1992', '19let', '19x', '1_', '1_0', '1_04x', '1_0f', '1_0x', '1_0xe', '1_n', '1a', '1b', '1c', '1c_2', '1column', '1e', '1figure', '1k', '1m', '1n', '1st', '1the', '1x', '1y', '1z', '2', '20', '200', '2000', '20000', '2002b', '2003', '2008', '2009', '201', '2010', '2012', '2012b', '2013', '2014', '2015', '2016', '2017', '2020', '2023', '207', '20c', '20i', '20let', '20th', '20x', '20y', '21', '210', '2100', '212', '215', '216', '22', '220', '225', '22x', '23', '230', '23the', '24', '240', '240g', '243', '243x', '2475', '24i', '24x', '24xy', '24y', '25', '250', '2500', '252', '2520', '253', '255', '256', '25a', '25px', '25x', '25y', '26', '260', '261', '26i', '26x', '27', '270', '2700', '2717y', '2727', '27i', '27x', '27z_2z_3', '28', '288', '28x', '29', '29x', '2_', '2_0', '2_0f', '2_1', '2_2', '2_i', '2a', '2a_1', '2a_2', '2a_8', '2a_9', '2ab', '2ac', '2acy', '2ar', '2as', '2at', '2at_1', '2at_2', '2ax', '2ay', '2b', '2b_1', '2bt', '2bx', '2by', '2c', '2c_0', '2c_1', '2c_3', '2c_r', '2column', '2cosx', '2cx', '2cxy', '2d', '2dt', '2dx', '2dy', '2e', '2ex', '2f', '2f_2', '2fy', '2g', '2gx', '2i', '2i3', '2if', '2j', '2k', '2let', '2logx', '2logxdx', '2m', '2mx', '2n', '2nd', '2p', '2p_1', '2p_2', '2p_6', '2px', '2q', '2qy', '2r', '2region', '2s', '2sin', '2t', '2the', '2x', '2x_1', '2x_2', '2x_3', '2xi', '2xlogxdx', '2xn', '2xy', '2y', '2yi', '2yz', '2z', '2z_2', '2z_3', '2𝑎', '2𝑏', '2𝑓𝑦', '2𝑔𝑥', '2𝑖', '2𝑛', '2𝑡', '2𝑥', '2𝑥𝑦', '2𝑦', '2𝜃', '2𝜋', '3', '30', '300', '3000', '30000', '301', '3069', '30th', '30x', '30y', '31', '31218123', '315', '3195', '32', '321', '32x', '32y', '32𝑦', '33', '333', '3333', '334', '336', '337', '338', '34', '343', '34x', '35', '351', '35m', '36', '361', '365', '368', '36x', '37', '3789108', '379', '38', '380', '39', '392', '3_', '3_0', '3_0f', '3_0x', '3_1', '3_1x', '3a', '3abc', '3ax', '3b', '3by', '3c', '3cy', '3d', '3f', '3i', '3j', '3k', '3m', '3n', '3p', '3q', '3r', '3rd', '3s_n', '3t', '3x', '3xy', '3y', '3z', '3𝑥', '3𝑦', '4', '40', '400', '4096', '41', '416', '42', '420', '43', '44', '45', '450', '46', '46x', '47', '48', '49', '4_1', '4a', '4ab', '4ac', '4at', '4ax', '4ay', '4b', '4c', '4c_2', '4cy', '4d', '4e', '4f', '4i', '4k', '4m', '4n', '4r', '4s_', '4t', '4x', '4xy', '4y', '4z', '4𝑓', '4𝑥', '4𝑦', '5', '50', '500', '5040', '50a', '51', '52', '5253', '53', '5346', '54', '543', '55', '56', '57', '58', '59', '5_', '5a', '5b', '5i', '5k', '5n', '5p', '5p_3', '5t', '5x', '5xy', '5y', '5𝑖', '5𝑥', '6', '60', '600', '61', '62', '625', '63', '64', '648', '65', '6561', '66', '660', '68', '69', '6_', '6a', '6at', '6ax', '6b', '6c_4', '6i', '6k', '6p', '6s_', '6t', '6x', '6xy', '6y', '6z', '7', '70', '700', '72', '73', '75', '78', '79', '7i', '7n', '7th', '7x', '7y', '8', '80', '81', '82', '83', '84', '85', '87', '88', '89', '8c_r', '8i', '8t', '8x', '8y', '9', '90', '902', '92', '95', '96y', '97', '99', '999', '9_', '9a', '9c_3', '9i', '9th', '9x', '9y', '_', '_0', '_0e', '_0f', '_0x', '_1', '_2', '_3', '_4', '_5', '___', '____', '_____', '______', '__ ...

# %%
count_vect.stop_words_
# Out:
# {'magnitudes',
#  'defining',
#  'pw',
#  'external',
#  'mechanical',
#  'derive',
#  'sliding',
#  'predict',
#  'log_38',
#  'knows',
#  'codes',
#  '45t',
#  'az_2',
#  'interesect',
#  'log_22',
#  'march',
#  'chairs',
#  'account',
#  'engineering',
#  'axisrotation',
#  'forecasts',
#  'sin62',
#  'a𝑥',
#  'cos179',
#  'ghar',
#  'log_2n',
#  'germany',
#  'discrete',
#  'frac18',
#  'short',
#  'parcels',
#  'mediterranean',
#  'bonded',
#  '𝐶_4',
#  'pentagon',
#  'farther',
#  'mc_1',
#  'leq3',
#  'daily',
#  'playstation',
#  'pears',
#  '512',
#  'flow',
#  'expanses',
#  'occuring',
#  'slack',
#  'nxdx',
#  'nn',
#  'plates',
#  '𝐶_8',
#  'thee',
#  'etc',
#  'lost',
#  '_x2',
#  'inclination',
#  '7c_1',
#  'file',
#  '9192',
#  'neq0',
#  'husband',
#  'propositions',
#  'came',
#  '22t',
#  'pug',
#  'lineif',
#  '8z',
#  'goa',
#  'able',
#  'n_0f',
#  'lawiii',
#  'cirumscribes',
#  '150x',
#  'd_',
#  'geq3',
#  '7_4f',
#  'rationals',
#  'rabbits',
#  'chocolates',
#  'chooses',
#  'log_ab',
#  '7c_5',
#  'nc_6',
#  'bat',
#  'notebook',
#  'hot',
#  'pf_1',
#  'mass',
#  '7dx',
#  'int7e',
#  '594',
#  'sine',
#  'asks',
#  'deal',
#  'log_9x',
#  'qd',
#  'fast',
#  'frac4',
#  'qz',
#  'nr',
#  '666',
#  'sin275',
#  '7_2f',
#  'doubles',
#  'log_8128',
#  'pss',
#  'library',
#  'ans',
#  'corresponds',
#  'licences',
#  'lamp',
#  'bell',
#  '77',
#  'united',
#  'alwaysiii',
#  'application',
#  'combinatorial',
#  '4𝑖',
#  'public',
#  '5c_3x',
#  'bm',
#  '3i2y',
#  'loan',
#  '49n',
#  'equaliv',
#  'eventswhich',
#  'examine',
#  '567724',
#  '𝐴𝑘𝑠',
#  'logics',
#  'bolts',
#  '_xf',
#  'is4if',
#  '2w',
#  '64k',
#  '3z_2',
#  '6n',
#  'aog',
#  'nw',
#  'gravity',
#  'sines',
#  '3𝑓',
#  'p_0',
#  'illness',
#  'diffrential',
#  'laid',
#  'mc_0',
#  '8_',
#  'h𝑥',
#  'accessible',
#  'mouse',
#  'hunter',
#  'pm4',
#  'westwards',
#  'september',
#  'birthday',
#  'k2',
#  'melts',
#  'log_e16',
#  'draws',
#  'a_4h_7',
#  'differentials',
#  'jee',
#  'alloy',
#  'dairy',
#  'kunal',
#  '5000',
#  'covering',
#  'complementary',
#  'met',
#  '4bx',
#  'infer',
#  'passess',
#  'integrate',
#  '𝐶𝐹',
#  'octant',
#  'moivre',
#  'log_56',
#  'nc_j',
#  'c_1c_',
#  'ptq',
#  'ixx',
#  'additioni',
#  'geq2',
#  'prices',
#  'cota',
#  'fnd',
#  'leads',
#  'moduleafter',
#  'le15',
#  '7c_7',
#  'confirms',
#  'h_3',
#  '2sin2x',
#  'napier',
#  'human',
#  '4_3',
#  'm_1m_2',
#  '3dx',
#  'agrees',
#  'fingers',
#  'followed',
#  '9z_1z_3z_4',
#  'mrn',
#  'pc_2',
#  'mrs',
#  'log_24',
#  'prod_',
#  'p_1q_0',
#  '21y',
#  'fan',
#  'cotc',
#  'a_2c_1',
#  'partly',
#  '157',
#  'doctor',
#  'receive',
#  '𝐶_𝑛',
#  '5d',
#  '510',
#  'eventsiii',
#  'husky',
#  'toss',
#  'ge26',
#  'equationi',
#  'incomplete',
#  'lose',
#  '76',
#  'dg',
#  'parabolaif',
#  'sinxdx',
#  '5c',
#  'get',
#  '513x',
#  '3x_n',
#  'log_x8',
#  'orders',
#  'kf',
#  '4if',
#  '2hxy',
#  'are1points',
#  'log_28',
#  'cos3a',
#  '4h',
#  'aces',
#  'northwards',
#  'captain',
#  'cos𝜃',
#  '8xy',
#  '6th',
#  'shadow',
#  'intervention',
#  'sin2tdt',
#  'lowest',
#  'rank',
#  'log_816',
#  'a_12',
#  '2011b',
#  'beings',
#  'collections',
#  'iy_0',
#  'company',
#  'whatever',
#  '2f_1f_2',
#  'log_cb',
#  'shaped',
#  '__',
#  'a4',
#  'inscribe',
#  'multiply',
#  'c_0c_r',
#  'pi_0',
#  'powerboat',
#  'carromboard',
#  'inviting',
#  'situated',
#  'frac34',
#  'nx_i',
#  '4095',
#  'c_2c_',
#  'illuminated',
#  'discarded',
#  'buddh',
#  'equivalently',
#  'iistraight',
#  '9kx',
#  'oe',
#  'directories',
#  '156',
#  '4c_2x',
#  'layers',
#  'ithe',
#  '3e',
#  'endlessly',
#  'le4y',
#  '3p_2',
#  'description',
#  '4000',
#  'attempting',
#  'pmn',
#  'pattern',
#  '3abx',
#  'rahul',
#  'marksnumber',
#  '108',
#  'pm5y',
#  '7𝑚',
#  'bpc',
#  'decompose',
#  'endeanoel',
#  'jack',
#  'f_2o',
#  'cdot8',
#  '8k',
#  '109',
#  'enclose',
#  'banana',
#  'omitted',
#  '7c_3x',
#  'poodle',
#  'erasing',
#  '____0',
#  'grows',
#  'chihuahua',
#  'geometrically',
#  'log_34',
#  'functionquadrant',
#  '4c_0',
#  'ln3',
#  'perpendicularly',
#  'converted',
#  'cs',
#  'nearer',
#  'log_78',
#  '5th',
#  '567',
#  'hands',
#  'oi',
#  'daynumber',
#  'depth',
#  'formulated',
#  '2228',
#  'refuses',
#  '7c_2',
#  'reflexive',
#  'mqr',
#  'int4',
#  'locality',
#  'inersection',
#  'b𝑦',
#  'piles',
#  '521',
#  'otherwise',
#  'ce',
#  'exam',
#  'delta_1',
#  'geq2x',
#  'loci_mystery',
#  'iiconsider',
#  'betwen',
#  '𝐵_3',
#  '576',
#  'le7',
#  'cdot16',
#  'concur',
#  'cutting',
#  'n_1a_n',
#  'baseline',
#  'neighbours',
#  'exp',
#  'rectangles',
#  '75q',
#  'applicant',
#  'completes',
#  'october',
#  'sin75',
#  'onhyperbola',
#  'momentarily',
#  'log_3a',
#  'monthiii',
#  'dayoption',
#  '2g_1g_2',
#  'market',
#  '2iy',
#  'emanating',
#  'permuted',
#  'bhushan',
#  'cos2a',
#  'exchanged',
#  'oa_i',
#  '4c_s',
#  'literal',
#  'legal',
#  'isdifferentiable',
#  'considering',
#  'pm3',
#  'covert',
#  'flows',
#  'happen',
#  '2figure',
#  'c_7x',
#  'sin74',
#  'haryana',
#  'depicts',
#  '9ax',
#  'applicants',
#  'immediately',
#  '7𝜋',
#  '_cf',
#  '50x',
#  'joined',
#  'iiabscissa',
#  '4dividing',
#  'parabolic',
#  'entire',
#  'ci',
#  'cos3c',
#  'annual',
#  '21x',
#  'minimizes',
#  'maximums',
#  'record',
#  'centriod',
#  '𝐸_1',
#  'believe',
#  'cost',
#  'rain',
#  'log𝑎',
#  '520200',
#  'ea',
#  'recta',
#  'infty_',
#  'd_k',
#  'functioniiiiiiv',
#  'assistant',
#  'bases',
#  'pba',
#  'crew',
#  'eccentriciyt',
#  'approx',
#  'tip',
#  'frac1z',
#  'numberii',
#  'weighted',
#  '10b',
#  'hydrochloric',
#  'log_232',
#  'jc_i',
#  'receiving',
#  'manchester',
#  'logx',
#  'np_4',
#  'fat',
#  '6500',
#  'hasonly',
#  'k𝑦',
#  '7a',
#  'cause',
#  'mathematicians',
#  'consistency',
#  'close',
#  'iiroots',
#  'canvas',
#  '78y',
#  'demand',
#  'cos1',
#  'currency',
#  'metal',
#  '3_2f',
#  'consulting',
#  'blocks',
#  'qth',
#  'log𝑏',
#  'zr',
#  'malayalam',
#  'constrained',
#  'thennumber',
#  'loyal',
#  'ze',
#  'halting',
#  '810',
#  'debate',
#  'theirs',
#  'a_rx',
#  '9n',
#  'frac45',
#  'august',
#  'leq4x',
#  '8𝑥',
#  'cos6x',
#  'alpha2',
#  'arguments',
#  '𝐵_1',
#  'grass',
#  'female',
#  '6ix',
#  '155',
#  'frac1y',
#  'madrid',
#  'failed',
#  'forward',
#  'bought',
#  '5ax',
#  'factorial',
#  'qpr',
#  'descending',
#  'sin𝛼',
#  'commonly',
#  'log_aa',
#  'concyclic',
#  'buys',
#  'mapping',
#  'cotb',
#  'dishonest',
#  'pi4',
#  'm0',
#  '98',
#  'boating',
#  'le4x',
#  'faced',
#  '9t',
#  'miles',
#  'home',
#  'oabcd',
#  'idempotent',
#  'dv',
#  'midterm',
#  'analysis',
#  'l_k',
#  'gave',
#  'master',
#  '9k',
#  'ln25',
#  'cv_x',
#  'h_7',
#  'theta_1z',
#  'implicity',
#  'mq',
#  'sin46',
#  'deck',
#  'ks_k',
#  'j_',
#  'distibuted',
#  'finger',
#  '153',
#  '3𝐷',
#  'rail',
#  '_𝑏',
#  'np_s',
#  'pile',
#  'sixteen',
#  'abscissas',
#  'pay',
#  'daughters',
#  'oqd',
#  'medicine',
#  'coaxal',
#  '850',
#  '_i',
#  'li9ne',
#  'eb',
#  'november',
#  'l_4',
#  '680',
#  'cot150',
#  'poq',
#  '7z',
#  'positivie',
#  '57x',
#  'le8x',
#  'cms',
#  'differentiating',
#  'exterior',
#  '6c',
#  'e_3',
#  'include',
#  'arc',
#  'log𝑐',
#  '5353',
#  'hypotenuse',
#  'thenmaximum',
#  '800',
#  'sin8',
#  '6𝑦',
#  'male',
#  'coloured',
#  'log_43',
#  'rainbow',
#  '8a',
#  'a_1a_',
#  'approaches',
#  'certainly',
#  'bisecting',
#  '3u',
#  'posed',
#  'boundary',
#  'mf_1nf_2',
#  'ey',
#  'intoidentify',
#  'pessimistic',
#  '3c_4',
#  'delta_2',
#  'houses',
#  'cos2t',
#  '4𝑥𝑦',
#  'bomb',
#  'abq',
#  'bot',
#  '8th',
#  'jaya',
#  'independently',
#  'exradius',
#  'dataclass',
#  'shooting',
#  'az_1',
#  'fatal',
#  'aj',
#  'konkan',
#  'factional',
#  'mistress',
#  'c_nx',
#  'heightweightmean',
#  'jerry',
#  'participants',
#  'omn',
#  'minimal',
#  'lamps',
#  'fund',
#  'du',
#  'conducted',
#  'earth',
#  'pf_2',
#  'necklaces',
#  'managed',
#  'objectsstatement',
#  'h_1h_2',
#  '4a_9',
#  'ln5x',
#  'arround',
#  'is18the',
#  'nm',
#  'bicycle',
#  'cpb',
#  'sin5',
#  'lawii',
#  'cos7',
#  'to2a',
#  'conical',
#  'nearby',
#  'int_3',
#  'big',
#  'participant',
#  'january',
#  'n2',
#  '3x_2',
#  '40000',
#  'mt',
#  'asian',
#  '_e',
#  'nj',
#  '8𝑦',
#  'expresion',
#  'fin',
#  'df_1',
#  'deposited',
#  'iw',
#  'enough',
#  '𝐴_2',
#  'gifts',
#  '737',
#  '𝑉𝑎𝑟',
#  '3c_1x',
#  '64z_3z_1',
#  'mrt',
#  '2h',
#  'f_1mn',
#  '5bx',
#  'eastwards',
#  'click',
#  'properly',
#  'evaluating',
#  'commute',
#  'hindustan',
#  'delta_3',
#  'millioniv',
#  'amout',
#  'a_1a_4',
#  'however',
#  'followinglist',
#  'isf',
#  'jill',
#  'n_k',
#  'kink',
#  'gap',
#  'adjacently',
#  'oac',
#  'cos23',
#  'ni',
#  'progress',
#  'rectums',
#  'hx',
#  'aboc',
#  '_r',
#  'exams',
#  'coming',
#  'falling',
#  'w_2',
#  'rajdhani',
#  'frac23a',
#  'chapter',
#  'circumscribed',
#  '4z_1z_2z_4',
#  'doesn',
#  'pays',
#  'cot3x',
#  'emitted',
#  'activitythere',
#  'neighbour',
#  'excluded',
#  'cars',
#  '𝑊',
#  'abut',
#  'minimums',
#  'pm1',
#  '9e',
#  'disjointregion',
#  '_m',
#  'conormal',
#  'latera',
#  'moreover',
#  'antilog',
#  'le36',
#  'rakshit',
#  'b_s',
#  'factorisation',
#  'continue',
#  '2given',
#  '3_i',
#  'december',
#  '5e',
#  'explain',
#  'comprising',
#  '3figure',
#  'cde',
#  'indianoil',
#  'april',
#  'garden',
#  '685',
#  'involving',
#  'portioned',
#  'le3x',
#  'pp',
#  '6a_8',
#  'df_2',
#  '93',
#  'oncircleif',
#  '3ab',
#  'expansions',
#  '4xyz',
#  'frac72',
#  '94',
#  'enlarge',
#  'absence',
#  'bolt',
#  '3z_1',
#  'planar',
#  'frac1k',
#  'to3if',
#  'log_7',
#  '3p_3',
#  'g_1g_2',
#  'paths',
#  '3c_2',
#  '𝑊𝑅𝑂𝐺𝑁',
#  'wheels',
#  'classfrequency',
#  'bxy',
#  'pac',
#  '417',
#  '729',
#  'sharp',
#  'factorized',
#  '4z_2',
#  'kr',
#  'flag',
#  'dicitionary',
#  'dat',
#  'bz_1',
#  '561',
#  'log_20',
#  'ministers',
#  'prq',
#  'shares',
#  'int_k',
#  'log_yx',
#  'dash',
#  'escape',
#  'conversion',
#  'indirect',
#  'rearrange',
#  'journey',
#  'gcd',
#  'sin4a',
#  'checking',
#  'd_3',
#  '3g',
#  'pap',
#  '96',
#  '54x',
#  'skewed',
#  'geq1',
#  '111',
#  'pd',
#  'theta_0z',
#  'kq',
#  '513',
#  'pointing',
#  'orthonormal',
#  'methodheight',
#  'log_97',
#  'bsin',
#  'motor',
#  '6c_2x',
#  'passport',
#  'brakes',
#  'zeroiii',
#  'hae',
#  'differentiations',
#  'cot135',
#  'rapidly',
#  'cos𝛼',
#  '7creating',
#  '3_2',
#  '4500',
#  'posted',
#  'iifor',
#  '5f',
#  'pth',
#  'expanding',
#  'apply',
#  '𝐵_2',
#  'cn',
#  'finitely',
#  'edx',
#  'fails',
#  'imposed',
#  'i_5',
#  'nz',
#  'factoring',
#  'predicted',
#  'coincident',
#  'navimumbai',
#  'often',
#  'abcde',
#  'leq8',
#  'probablity',
#  'she',
#  'hh',
#  'earners',
#  '7_',
#  'centoid',
#  'epsilon',
#  'pendulum',
#  'males',
#  'elimination',
#  'languages',
#  'qv',
#  'endanoele',
#  'theta_0',
#  '𝐶_0',
#  'log_216',
#  'log_41024',
#  'language',
#  'blackboard',
#  'hence',
#  'plotted',
#  'iscontinuous',
#  'bfc',
#  'refers',
#  '453',
#  '2u',
#  'pdx',
#  'completely',
#  '3ix',
#  'occupied',
#  'operating',
#  'closest',
#  'dr',
#  'interesting',
#  '8z_1z_2',
#  'july',
#  'ninth',
#  'accommodate',
#  'frac12p',
#  'orange',
#  '4lnx',
#  'pm10',
#  'agenumber',
#  '4xdx',
#  '3𝑖',
#  'producing',
#  'june',
#  'cv_y',
#  '8e',
#  '5m',
#  '1530',
#  'firms',
#  '5c_k',
#  '10th',
#  'ibt',
#  'directionwe',
#  'p3',
#  '723',
#  'characteristics',
#  'extends',
#  'cmsnumber',
#  'near',
#  '3c_r',
#  'cj',
#  'flaws',
#  '414141',
#  '840',
#  '152',
#  'bike',
#  'bags',
#  'gd',
#  'indigo',
#  'kxy',
#  'frac32x',
#  'neglecting',
#  '3ac',
#  '4g',
#  'manners',
#  '8f',
#  'qp',
#  '90000',
#  'halt',
#  '4th',
#  'mango',
#  'chandigarh',
#  'mantissa',
#  'a_0x',
#  'industry',
#  'moderately',
#  'formation',
#  'distributionclasses',
#  'across',
#  'bk',
#  'al',
#  'quartile',
#  'theletters',
#  '4other',
#  'algebra',
#  'con',
#  'cancelling',
#  '7lnx',
#  'int2sec',
#  'parbola',
#  'guessing',
#  'brand',
#  'pascal',
#  'partner',
#  '5c_1x',
#  'obd',
#  'alive',
#  'questionif',
#  'intuition',
#  'log_2128',
#  'differences',
#  'reasoning',
#  'eyes',
#  'labrador',
#  'front',
#  'cot15',
#  'cos𝑎𝑥',
#  'opqrs',
#  'ef',
#  'log_512',
#  '𝐵𝐶',
#  'passenger',
#  'frac1n',
#  'ion',
#  'rc_k',
#  'boring',
#  '67',
#  'ot',
#  'cot2',
#  'color',
#  'governed',
#  'aod',
#  '𝐴𝐵',
#  'a_m',
#  'frac43ps',
#  'parablas',
#  '414',
#  '715',
#  '2187',
#  'cot3',
#  '4_2f',
#  'ignoring',
#  'oscillation',
#  ...}

# %%
count_vect
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=3500, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='\\w{1,}', tokenizer=None,
#         vocabulary=None)

# %%
count_vect.get_params
# Out:
# <bound method BaseEstimator.get_params of CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=3500, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='\\w{1,}', tokenizer=None,
#         vocabulary=None)>
