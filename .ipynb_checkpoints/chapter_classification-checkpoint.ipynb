# %% [markdown]
# ## Imports

# %%
# Sklearn module
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas as pd, xgboost, numpy, textblob, string

# Keras stuff -- Commented out as not used yet
# from keras.preprocessing import text, sequence
# from keras import layers, models, optimizers

# Regex
import re

# Stopwords
import nltk
nltk.download('stopwords')
stop = nltk.corpus.stopwords.words('english')
import json

from pylatexenc.latex2text import LatexNodes2Text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pritamsukumar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Data Preparation

# %%
subject_to_check = 'MTH'
# Load the dataset
labels, texts = [], []
with open('data/qs_topicwise.json') as json_data:
    all_questions = json.load(json_data)

words_to_remove = ["rightarrow", "hence", "frac", "text", "sqrt", "times", "value", "amp", "statement", "will", "equal", "number", "tan", "now", "can", "two", "get", "true", "lambda"]
# words_to_remove += stop

data_df = pd.DataFrame(columns=['curriculum', 'subject', 'question_text', 'chapter'])
questions = []
i = 0

# Regex pattern for keeping only alphabets and numbers
pattern = re.compile('[^[:alnum:]]+')
nonutf8pattern = re.compile('[\u0080-\uffff]')
questions = all_questions[1:2]

for question in all_questions:
    try: # So that python doesn't crash on individual question exceptions
        question_text = question['question_text'].lower()
        
        question_text = pattern.sub(" ", question_text)
        question_text = nonutf8pattern.sub(" ", question_text)


        # Remove extra whitespaces
        question_text = " ".join([word for word in question_text.split() if word not in words_to_remove])
        question_text = " ".join(question_text.split())

        
        # Keep only alphanumeric characters
        
        subject = question['subject']
        curriculum = question['curriculum']
        grade = question['grade']
        curr_question = {}
        if("JEE" in curriculum and subject in subject_to_check):
            data_df.loc[i] = [curriculum, subject, question_text, question['chapter']]
            i += 1
    except Exception as e:
        print(e)

trainDF = pd.DataFrame(columns=['text', 'label'])

# trainDF.replace(words_to_replace, "")
trainDF['text'] = data_df['question_text']
trainDF['label'] = data_df['chapter']

# %% [markdown]
# ### Split into training and testing folds

# %%
# Split data into training and testing folds

train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'], test_size=0.2)

print(len(train_x), len(valid_x) )

# Label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)
# Out:
# 5583 1396

# %% [markdown]
# # Feature creation

# %%
# ----- FEATURE ENGINEERING -----
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=3513)
X = count_vect.fit_transform(trainDF['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xtrain_count_binary = xtrain_count
xtrain_count_binary[xtrain_count_binary != 0] = 1

xvalid_count =  count_vect.transform(valid_x)
xvalid_count[xvalid_count != 0] = 1
xvalid_count_dense = xvalid_count.todense().astype('str')

# %%
x = count_vect.vocabulary_
y = list(x.keys() )
print(sorted(y))
# Out:
# ['0', '00', '000', '000001', '0001', '0002', '002', '01', '02', '025', '04x', '07', '0a', '0c', '0e', '0f', '0x', '0xe', '0z', '1', '10', '100', '1000', '10000', '100000', '1000c', '1001', '100d', '100x', '101', '1011', '1011121314frequency', '1012', '102', '1024', '103', '104', '105', '106', '107', '108', '1080', '109', '10ax', '10b', '10cx', '10i', '10th', '10x', '10y', '11', '110', '11040', '111', '112', '115', '117', '119', '11b', '11d', '11i', '11if', '11t', '11x', '11y', '12', '120', '120g', '121', '1234', '125', '126', '127', '128', '12a', '12i', '12m', '12t', '12x', '12y', '12z', '13', '130', '130p', '135', '136', '1361', '137', '139', '13x', '14', '140', '1400', '1410', '1413', '144', '145', '1450', '1457', '149', '14a', '14x', '14y', '15', '150', '150x', '15101051', '152', '153', '1530', '155', '156', '157', '15b', '15i', '15th', '15x', '16', '160', '162', '164', '169', '16ax', '16q', '16x', '16y', '16z', '17', '1720', '175', '178', '17f', '17th', '17x', '18', '180', '1800', '183', '185', '18e', '18i', '18x', '18xy', '18y', '18z', '18𝑦', '19', '192', '19202122', '192x', '1958', '196', '1986', '1992', '19let', '19x', '1a', '1b', '1c', '1column', '1e', '1f', '1figure', '1g', '1h', '1k', '1m', '1mn', '1n', '1nf', '1q', '1s', '1st', '1t', '1the', '1x', '1y', '1z', '1𝑥', '1𝑦', '2', '20', '200', '2000', '20000', '2002b', '2003', '2008', '2009', '201', '2010', '2011b', '2012', '2012b', '2013', '2013f', '2014', '2015', '2016', '2017', '2020', '2023', '207', '20c', '20i', '20let', '20th', '20x', '20y', '21', '210', '2100', '212', '2128', '215', '216', '2187', '21x', '21y', '22', '220', '2228', '225', '22j', '22t', '22x', '22xdx', '23', '230', '232', '23the', '24', '240', '240g', '243', '243x', '2475', '24i', '24x', '24xy', '24y', '25', '250', '2500', '252', '2520', '253', '255', '256', '25a', '25px', '25x', '25y', '26', '260', '261', '26i', '26x', '27', '270', '2700', '2717y', '2727', '27i', '27x', '27z', '28', '288', '28x', '29', '29x', '2a', '2ab', '2ac', '2acy', '2ar', '2as', '2at', '2ax', '2ay', '2b', '2bt', '2bx', '2by', '2c', '2column', '2cosx', '2cx', '2cxy', '2d', '2dt', '2dx', '2dy', '2e', '2ex', '2f', '2figure', '2fy', '2g', '2given', '2gx', '2h', '2hxy', '2i', '2i3', '2if', '2j', '2k', '2m', '2mx', '2n', '2nd', '2p', '2px', '2q', '2r', '2s', '2sin', '2t', '2the', '2x', '2xy', '2y', '2yi', '2z', '2𝑏', '2𝑓𝑦', '2𝑔𝑥', '2𝑖', '2𝑛', '2𝑥', '2𝑦', '3', '30', '300', '3000', '30x', '31', '32', '321', '32x', '32y', '33', '34', '35', '36', '360', '361', '365', '36x', '37', '38', '39', '392', '3a', '3abc', '3ax', '3b', '3by', '3c', '3cy', '3d', '3f', '3i', '3j', '3k', '3m', '3n', '3p', '3q', '3r', '3rd', '3s', '3t', '3x', '3xy', '3y', '3z', '3𝑥', '3𝑦', '4', '40', '400', '4096', '41', '416', '42', '420', '43', '44', '45', '450', '46', '460', '46x', '47', '48', '49', '4a', '4ab', '4ac', '4at', '4ax', '4ay', '4b', '4c', '4cy', '4d', '4e', '4f', '4h', '4i', '4k', '4m', '4n', '4r', '4s', '4t', '4x', '4xy', '4y', '4z', '4𝑓', '4𝑥', '4𝑦', '5', '50', '500', '5040', '50a', '51', '512', '52', '521', '5253', '53', '5346', '5353', '54', '543', '55', '56', '560', '57', '58', '59', '5a', '5b', '5c', '5i', '5k', '5n', '5p', '5q', '5t', '5th', '5x', '5xy', '5y', '5𝑖', '5𝑥', '6', '60', '600', '6000', '61', '62', '625', '63', '6300', '64', '648', '64k', '64z', '65', '6500', '654', '6561', '66', '660', '666', '67', '68', '680', '685', '69', '6a', '6at', '6ax', '6b', '6bx', '6c', '6f', '6i', '6ix', '6k', '6p', '6s', '6t', '6x', '6xy', '6y', '6z', '7', '70', '700', '72', '73', '75', '78', '79', '7c', '7i', '7n', '7th', '7x', '7y', '8', '80', '81', '82', '83', '84', '85', '87', '88', '89', '8c', '8i', '8t', '8x', '8y', '8z', '9', '90', '902', '92', '95', '96y', '97', '99', '999', '9a', '9c', '9i', '9th', '9x', '9y', 'a', 'aa', 'ab', 'abbc', 'abbcabbc', 'abc', 'abcd', 'abcdef', 'about', 'above', 'abscissa', 'absolute', 'ac', 'acb', 'acceleration', 'according', 'ace', 'acid', 'acidic', 'acidity', 'across', 'activity', 'activitythere', 'actual', 'acute',  ...

# %%
count_vect.stop_words_
# Out:
# {'2iy',
#  '2kx',
#  '2let',
#  '2logx',
#  '2logxdx',
#  '2o',
#  '2qy',
#  '2region',
#  '2sin2x',
#  '2tf',
#  '2u',
#  '2w',
#  '2xi',
#  '2xlogxdx',
#  '2xn',
#  '2yz',
#  '2𝑎',
#  '2𝑡',
#  '2𝑥𝑦',
#  '2𝜃',
#  '2𝜋',
#  '30000',
#  '301',
#  '3069',
#  '30th',
#  '30y',
#  '31218123',
#  '315',
#  '3195',
#  '32𝑦',
#  '333',
#  '3333',
#  '334',
#  '336',
#  '337',
#  '338',
#  '343',
#  '34x',
#  '351',
#  '35m',
#  '368',
#  '3789108',
#  '379',
#  '380',
#  '3ab',
#  '3abx',
#  '3ac',
#  '3dx',
#  '3e',
#  '3figure',
#  '3g',
#  '3i2y',
#  '3ix',
#  '3mn',
#  '3u',
#  '3𝐷',
#  '3𝑓',
#  '3𝑖',
#  '3𝑚',
#  '4000',
#  '40000',
#  '4095',
#  '41024',
#  '414',
#  '414141',
#  '417',
#  '4200',
#  '432',
#  '438',
#  '4500',
#  '453',
#  '45t',
#  '466',
#  '475',
#  '482',
#  '49n',
#  '4bx',
#  '4dividing',
#  '4dx',
#  '4g',
#  '4if',
#  '4lnx',
#  '4other',
#  '4th',
#  '4xdx',
#  '4xyz',
#  '4𝑖',
#  '4𝑥𝑦',
#  '5000',
#  '50b',
#  '50d',
#  '50x',
#  '510',
#  '513',
#  '513x',
#  '520200',
#  '540',
#  '54x',
#  '5500',
#  '561',
#  '567',
#  '567724',
#  '576',
#  '57x',
#  '585',
#  '586',
#  '594',
#  '5ax',
#  '5bx',
#  '5d',
#  '5e',
#  '5f',
#  '5kx',
#  '5m',
#  '6n',
#  '6th',
#  '6𝑎',
#  '6𝑥',
#  '6𝑦',
#  '71',
#  '715',
#  '720',
#  '723',
#  '729',
#  '72x',
#  '737',
#  '74x',
#  '75q',
#  '76',
#  '77',
#  '777',
#  '78y',
#  '7a',
#  '7abc',
#  '7creating',
#  '7dx',
#  '7lnx',
#  '7z',
#  '7𝑚',
#  '7𝜋',
#  '800',
#  '80y',
#  '810',
#  '8128',
#  '816',
#  '840',
#  '850',
#  '8a',
#  '8e',
#  '8f',
#  '8iz',
#  '8k',
#  '8th',
#  '8xy',
#  '8𝑥',
#  '8𝑦',
#  '900',
#  '90000',
#  '91',
#  '916238457',
#  '9192',
#  '93',
#  '94',
#  '96',
#  '98',
#  '992',
#  '9999',
#  '9ax',
#  '9e',
#  '9f',
#  '9k',
#  '9kx',
#  '9n',
#  '9t',
#  '9z',
#  'a4',
#  'abcde',
#  'abcx',
#  'able',
#  'aboc',
#  'abq',
#  'abscissas',
#  'absence',
#  'abut',
#  'abx',
#  'accessible',
#  'accommodate',
#  'account',
#  'accuracy',
#  'aces',
#  'agenumber',
#  'agrees',
#  'aj',
#  'ak',
#  'akhilesh',
#  'al',
#  'algebra',
#  'alive',
#  'allowable',
#  'alwaysiii',
#  'amout',
#  'amplitude',
#  'analysis',
#  'annual',
#  'ans',
#  'antilog',
#  'aod',
#  'aog',
#  'applicant',
#  'applicants',
#  'application',
#  'applies',
#  'apply',
#  'approaches',
#  'approx',
#  'approximations',
#  'appu',
#  'april',
#  'arc',
#  'are1points',
#  'arguments',
#  'arround',
#  'asian',
#  'asks',
#  'assigned',
#  'assistant',
#  'attained',
#  'attempting',
#  'august',
#  'authorities',
#  'axisrotation',
#  'a𝑥',
#  'backward',
#  'bags',
#  'banana',
#  'baseline',
#  'bases',
#  'bat',
#  'bb',
#  'beams',
#  'beings',
#  'believe',
#  'bell',
#  'belowthe',
#  'betwen',
#  'bfc',
#  'bhushan',
#  'completely',
#  'female',
#  'fencing',
#  'file',
#  'fin',
#  'finger',
#  'fingers',
#  'finitely',
#  'firms',
#  'flag',
#  'flaws',
#  'flow',
#  'flows',
#  'fnd',
#  'followed',
#  'followinglist',
#  'forecasts',
#  'formation',
#  'formulated',
#  'forward',
#  'frac12p',
#  'frac15',
#  'frac18',
#  'frac1k',
#  'frac1m',
#  'frac1n',
#  'frac1y',
#  'frac1z',
#  'frac23a',
#  'frac32x',
#  'frac34',
#  'frac35',
#  'frac4',
#  'frac43ps',
#  'frac45',
#  'frac72',
#  'freely',
#  'front',
#  'fuel',
#  'funciotn',
#  'functioniiiiiiv',
#  'functionquadrant',
#  'fund',
#  'gab',
#  'gap',
#  'garden',
#  'gave',
#  'gcd',
#  'gd',
#  'ge26',
#  'ge2y',
#  'ge4x',
#  'ge8',
#  'geometrically',
#  'geometry',
#  'geq1',
#  'geq2',
#  'geq2x',
#  'geq3',
#  'germany',
#  'ghar',
#  'gifts',
#  'goa',
#  'governed',
#  'graphical',
#  'grass',
#  'gravitational',
#  'gravity',
#  'grows',
#  'guessing',
#  'hae',
#  'halt',
#  'halting',
#  'hands',
#  'happen',
#  'haryana',
#  'hasonly',
#  'heightweightmean',
#  'hh',
#  'hindustan',
#  'home',
#  'hot',
#  'houses',
#  'however',
#  'human',
#  'hunter',
#  'husband',
#  'husky',
#  'hx',
#  'hydrochloric',
#  'hypotenuse',
#  'h𝑥',
#  'ibt',
#  'idempotent',
#  'ignoring',
#  'iiabscissa',
#  'iiconsider',
#  'iifor',
#  'iiplane',
#  'iiroots',
#  'iistraight',
#  'illness',
#  'illuminated',
#  'immediately',
#  'implicity',
#  'imposed',
#  'inclination',
#  'include',
#  'incomplete',
#  'independently',
#  'indianoil',
#  'indigo',
#  'indirect',
#  'individually',
#  'industry',
#  'inersection',
#  'inex',
#  'infer',
#  'int5',
#  'int7e',
#  'integera',
#  'integeriv',
#  'integrate',
#  'interesect',
#  'interesting',
#  'international',
#  'intervention',
#  'intoidentify',
#  'intuition',
#  'inviting',
#  'lamp',
#  'lamps',
#  'language',
#  'languages',
#  'latera',
#  'latusrecta',
#  'lawii',
#  'lawiii',
#  'lawiv',
#  'layers',
#  'le11',
#  'le15',
#  'le36',
#  'le3x',
#  'le4x',
#  'le4y',
#  'le7',
#  'le8x',
#  'leads',
#  'legal',
#  'leq3',
#  'leq4x',
#  'leq8',
#  'lettered',
#  'li9ne',
#  'library',
#  'licence',
#  'licences',
#  'lineif',
#  'listed',
#  'literal',
#  'ln25',
#  'ln3',
#  'ln3x',
#  'ln5x',
#  'lnx',
#  'loan',
#  'locality',
#  'loci',
#  'log6',
#  'logics',
#  'logx',
#  'log𝑎',
#  'log𝑏',
#  'log𝑐',
#  'lose',
#  'lost',
#  'lowest',
#  'loyal',
#  'm0',
#  'madrid',
#  'magnitudes',
#  'malayalam',
#  'male',
#  'males',
#  'managed',
#  'manchester',
#  'mango',
#  'manned',
#  'manners',
#  'mantissa',
#  'map',
#  'mapping',
#  'marathi',
#  'march',
#  'market',
#  'marksnumber',
#  'mass',
#  'master',
#  'mathematicians',
#  'maximums',
#  'maybe',
#  'mechanical',
#  'medicine',
#  'mediterranean',
#  'melts',
#  'menu',
#  'met',
#  'metal',
#  'methodheight',
#  'mf',
#  'midterm',
#  'miles',
#  'millioniv',
#  'minimal',
#  'minimizes',
#  'minimums',
#  'ministers',
#  'mistress',
#  'moderately',
#  'moduleafter',
#  'moivre',
#  'momentarily',
#  'monthiii',
#  'moreover',
#  'motor',
#  'mouse',
#  'mouth',
#  'mq',
#  'mqr',
#  'mrn',
#  'mrs',
#  'mrt',
#  'mt',
#  'mth',
#  'mu3',
#  'multiply',
#  'mystery',
#  'n128',
#  'n2',
#  'n8',
#  'nagpur',
#  'named',
#  'napier',
#  'narrow',
#  'navimumbai',
#  'ne4',
#  'near',
#  'nearby',
#  'nearer',
#  'necklaces',
#  'neglecting',
#  'neighbour',
#  'neighbours',
#  'neq0',
#  'opqrs',
#  'oqd',
#  'orange',
#  'orders',
#  'originating',
#  'orthonormal',
#  'oscillation',
#  'ot',
#  'others',
#  'otherwise',
#  'outer',
#  'output',
#  'p2',
#  'p3',
#  'pac',
#  'pairwise',
#  'pap',
#  'parbola',
#  'parcels',
#  'park',
#  'participant',
#  'participants',
#  'partly',
#  'partner',
#  'pascal',
#  'passenger',
#  'passess',
#  'passport',
#  'paths',
#  'patients',
#  'pattern',
#  'pay',
#  'pays',
#  'pba',
#  'pc',
#  'pd',
#  'pdx',
#  'pears',
#  'peer',
#  'pendulum',
#  'pentagon',
#  'permuted',
#  'perpendicularly',
#  'pessimistic',
#  'pi4',
#  'pile',
#  'piles',
#  'pink',
#  'pint',
#  'pl',
#  'planar',
#  'plates',
#  'playstation',
#  'plotted',
#  'plotting',
#  'pm1',
#  'pm10',
#  'pm3',
#  'pm4',
#  'pm5y',
#  'pmn',
#  'pnumber',
#  'pointing',
#  'poodle',
#  'poq',
#  'portioned',
#  'posed',
#  'positivie',
#  'posted',
#  'powerboat',
#  'pp',
#  'predict',
#  'predicted',
#  'prices',
#  'probablity',
#  'producing',
#  'progress',
#  'properly',
#  'propositions',
#  'prq',
#  'pss',
#  'pth',
#  'ptq',
#  'public',
#  'pug',
#  'pulled',
#  'putting',
#  'pw',
#  'qd',
#  'qp',
#  'qpr',
#  'qth',
#  'quartile',
#  'questionif',
#  'qv',
#  'qz',
#  'rabbits',
#  'rahul',
#  'rail',
#  'rain',
#  'rainbow',
#  'rajdhani',
#  'rakshit',
#  'rank',
#  'rapidly',
#  'rationals',
#  'rc',
#  'reached',
#  'reals',
#  'rearrange',
#  'reasoning',
#  'receive',
#  'receiving',
#  'record',
#  'recta',
#  'rectangles',
#  'rectums',
#  'refers',
#  'reflexive',
#  'refuses',
#  'regionsexpressionregion',
#  'registration',
#  'relationship',
#  'reloads',
#  'renowned',
#  'rent',
#  'repaying',
#  'repeat',
#  'repeats',
#  'replace',
#  'reported',
#  'reproduced',
#  'requirement',
#  'research',
#  'resp',
#  'result',
#  'resulted',
#  'retail',
#  'retaining',
#  'returned',
#  'reversing',
#  'revolutions',
#  'rgi',
#  'rhe',
#  'rightarrow3',
#  'rim',
#  'roles',
#  'roll',
#  'rootsequal',
#  'rootsno',
#  'roses',
#  'rounder',
#  'rpm',
#  'rpq',
#  'rules',
#  'running',
#  'ry',
#  's3',
#  'saharanpur',
#  'sailboat',
#  'sale',
#  'salesman',
#  'sanskrit',
#  'scalars',
#  'scale',
#  'schoolii',
#  'scientific',
#  'score',
#  'sec0',
#  'sec300',
#  'sec4',
#  'sec90',
#  'sections',
#  'secx',
#  'secxtanxdx',
#  'selections',
#  'self',
#  'send',
#  'september',
#  'session'}

# %%
count_vect
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='\\w{1,}', tokenizer=None,
#         vocabulary=None)

# %%
count_vect.get_params
# Out:
# <bound method BaseEstimator.get_params of CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='\\w{1,}', tokenizer=None,
#         vocabulary=None)>
